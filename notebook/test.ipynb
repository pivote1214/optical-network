# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('.'), os.path.pardir)))

from src.paths.algorithms.overall_optimization import NodePairClustering, NodePairClusteringParams

# %%
params = NodePairClusteringParams(
    n_ref_paths=1, 
    sim_metric='all-one', 
    linkage_method='average', 
    threshold=0.8, 
    criterion='distance', 
    cutoff=None, 
    length_metric='hop', 
    alpha=0.5
    )

path_set_generator = NodePairClustering('JPN12', 2, params)
path_set_generator.select_k_paths_all_pairs()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 13
#       1 params = NodePairClusteringParams(
#       2     n_ref_paths=1,
#       3     sim_metric='all-one',
#    (...)
#       9     alpha=0.5
#      10     )
#      12 path_set_generator = NodePairClustering('JPN12', 2, params)
# ---> 13 path_set_generator.select_k_paths_all_pairs()
#
# File ~/Documents/Codes/optical-network/src/paths/algorithms/overall_optimization.py:44, in NodePairClustering.select_k_paths_all_pairs(self)
#      43 def select_k_paths_all_pairs(self) -> dict[tuple[int, int], list[tuple[int]]]:
# ---> 44     clusters = self.node_pair_clustering()
#      45     selected_paths = self.select_path_set_from_clusters(clusters)
#      46     return selected_paths
#
# File ~/Documents/Codes/optical-network/src/paths/algorithms/overall_optimization.py:66, in NodePairClustering.node_pair_clustering(self)
#      64 paths_i = node_pair_paths[node_pairs[i]]
#      65 paths_j = node_pair_paths[node_pairs[j]]
# ---> 66 similarity = self._calc_node_pair_similarity(self.graph, paths_i, paths_j, edge_weight=self.params.sim_metric)
#      67 distance = 1 - similarity  # 距離に変換
#      68 distance_vector.append(distance)
#
# TypeError: NodePairClustering._calc_node_pair_similarity() got multiple values for argument 'edge_weight'
